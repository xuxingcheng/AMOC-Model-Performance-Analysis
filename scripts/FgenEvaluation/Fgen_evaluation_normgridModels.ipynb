# %%
import pandas
import matplotlib.pyplot as plt

# %%
import pickle

save_path = "/glade/work/stevenxu/AMOC_models/Fgen_Allmodels_norm.pkl"
with open(save_path, "rb") as f:
    Fgen_dict = pickle.load(f)
    
Fgen_dict
# Out:
# {'CAS-ESM2-0':             rho          Fgen      HeatFlux  FreshwaterFlux       AreaSum
#  0     1014.9975 -1.549657e-06  3.019561e-11   -1.549687e-06  2.276134e+08
#  1     1015.0025 -1.211609e-06  2.671982e-11   -1.211635e-06  1.310630e+08
#  2     1015.0075 -5.169075e-07  1.126402e-11   -5.169188e-07  6.483275e+07
#  3     1015.0125 -1.578906e-06  3.746585e-11   -1.578943e-06  1.944983e+08
#  4     1015.0175 -9.575572e-07  2.383283e-11   -9.575810e-07  1.917033e+08
#  ...         ...           ...           ...             ...           ...
#  2998  1029.9875  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
#  2999  1029.9925  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
#  3000  1029.9975  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
#  3001  1030.0025  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
#  3002  1030.0075  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
#
#  [3003 rows x 5 columns]}

# %%
for model, Fgen in Fgen_dict.items():
    Fgen_clip = Fgen[(Fgen['rho'] >1015)]
    plt.figure(figsize=(8,5))
    plt.plot(Fgen_clip['rho'], Fgen_clip['Fgen'],'--', label = f'Fgen {model}', color = 'black', linewidth=2)
    plt.plot(Fgen_clip['rho'], Fgen_clip['HeatFlux'], label=f'Heat Flux {model}')
    plt.plot(Fgen_clip['rho'], Fgen_clip['FreshwaterFlux'], label=f'Freshwater Flux {model}')

    plt.xlabel('rho')
    plt.ylabel('Fgen')
    plt.title(model + ' Fgen vs Rho')
    plt.grid(True)
    plt.legend(loc='upper left')
    plt.show()

# %%
Fgen_clip = Fgen[(Fgen['rho'] >1020)]
plt.figure(figsize=(8,5))
plt.plot(Fgen_clip['rho'], Fgen_clip['AreaSum'], label = 'Area Sum')

plt.xlabel('rho')
plt.ylabel('Area Sum')
plt.title('Area vs Rho')
plt.grid(True)
plt.legend(loc='upper right')
plt.show()
