# %%
import pandas
import matplotlib.pyplot as plt

# %%
import pickle

save_path = "/glade/work/stevenxu/AMOC_models/Fgen_Allmodels_streaming.pkl"
with open(save_path, "rb") as f:
    Fgen_dict = pickle.load(f)
    
Fgen_dict
# Out:
# {'ACCESS-CM2':           rho      Fgen  HeatFlux  FreshwaterFlux       AreaSum
#  0    1014.975 -0.019189 -0.015134       -0.004055  1.284596e+09
#  1    1015.025  0.009858 -0.001989        0.011847  1.205415e+09
#  2    1015.075  0.011526 -0.007454        0.018980  1.375081e+09
#  3    1015.125  0.005799 -0.001595        0.007394  1.118784e+09
#  4    1015.175  0.004873  0.003700        0.001173  1.250369e+09
#  ..        ...       ...       ...             ...           ...
#  297  1029.825  0.000000  0.000000        0.000000  0.000000e+00
#  298  1029.875  0.000000  0.000000        0.000000  0.000000e+00
#  299  1029.925  0.000000  0.000000        0.000000  0.000000e+00
#  300  1029.975  0.000000  0.000000        0.000000  0.000000e+00
#  301  1030.025  0.000000  0.000000        0.000000  0.000000e+00
#
#  [302 rows x 5 columns],
#  'ACCESS-ESM1-5':           rho      Fgen  HeatFlux  FreshwaterFlux       AreaSum
#  0    1014.975  0.023282  0.023254        0.000028  1.273069e+09
#  1    1015.025  0.015412  0.026789       -0.011378  1.393524e+09
#  2    1015.075  0.029960  0.019698        0.010262  1.278157e+09
#  3    1015.125 -0.004602  0.001815       -0.006418  1.368778e+09
#  4    1015.175  0.016556  0.022766       -0.006210  1.624956e+09
#  ..        ...       ...       ...             ...           ...
#  297  1029.825  0.000000  0.000000        0.000000  0.000000e+00
#  298  1029.875  0.000000  0.000000        0.000000  0.000000e+00
#  299  1029.925  0.000000  0.000000        0.000000  0.000000e+00
#  300  1029.975  0.000000  0.000000        0.000000  0.000000e+00
#  301  1030.025  0.000000  0.000000        0.000000  0.000000e+00
#
#  [302 rows x 5 columns],
#  'CAS-ESM2-0':           rho          Fgen      HeatFlux  FreshwaterFlux       AreaSum
#  0    1014.975 -5.033554e-07  1.073112e-11   -5.033661e-07  2.500031e+08
#  1    1015.025 -1.957188e-07  3.382583e-12   -1.957222e-07  8.692136e+07
#  2    1015.075 -3.309667e-07  5.275318e-12   -3.309720e-07  1.295222e+08
#  3    1015.125 -7.357133e-07  1.114719e-11   -7.357245e-07  2.840057e+08
#  4    1015.175 -6.565786e-07  1.330755e-11   -6.565919e-07  3.408068e+08
#  ..        ...           ...           ...             ...           ...
#  297  1029.825  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
#  298  1029.875  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
#  299  1029.925  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
#  300  1029.975  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
#  301  1030.025  0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
#
#  [302 rows x 5 columns],
#  'CanESM5':           rho      Fgen  HeatFlux  FreshwaterFlux       AreaSum
#  0    1014.975  0.182259  0.006662        0.175597  1.127985e+09
#  1    1015.025  0.240817  0.017365        0.223452  1.331218e+09
#  2    1015.075  0.220180  0.008982        0.211198  1.168072e+09
#  3    1015.125  0.174982  0.007919        0.167064  1.124395e+09
#  4    1015.175  0.144924  0.005293        0.139631  1.142260e+09
#  ..        ...       ...       ...             ...           ...
#  297  1029.825  0.000141  0.000095        0.000047  1.230335e+07
#  298  1029.875  0.000000  0.000000        0.000000  0.000000e+00
#  299  1029.925  0.000000  0.000000        0.000000  0.000000e+00
#  300  1029.975 -0.000099 -0.000011       -0.000087  2.450942e+07
#  301  1030.025  0.000000  0.000000        0.000000  0.000000e+00
#
#  [302 rows x 5 columns],
#  'CanESM5-1':           rho      Fgen  HeatFlux  FreshwaterFlux       AreaSum
#  0    1014.975  0.210428  0.010335        0.200093  1.183486e+09
#  1    1015.025  0.143900  0.014988        0.128912  1.377737e+09
#  2    1015.075  0.242710  0.002202        0.240508  1.401810e+09
#  3    1015.125  0.216694  0.018190        0.198504  1.208423e+09
#  4    1015.175  0.209351  0.011415        0.197936  1.406171e+09
#  ..        ...       ...       ...             ...           ...
#  297  1029.825  0.000000  0.000000        0.000000  0.000000e+00
#  298  1029.875  0.000000  0.000000        0.000000  0.000000e+00
#  299  1029.925  0.000000  0.000000        0.000000  0.000000e+00
#  300  1029.975  0.000000  0.000000        0.000000  0.000000e+00
#  301  1030.025  0.000000  0.000000        0.000000  0.000000e+00
#
#  [302 rows x 5 columns],
#  'FGOALS-f3-L':           rho      Fgen  HeatFlux  FreshwaterFlux       AreaSum
#  0    1014.975  0.000000  0.000000        0.000000  0.000000e+00
#  1    1015.025  0.000000  0.000000        0.000000  0.000000e+00
#  2    1015.075  0.000000  0.000000        0.000000  0.000000e+00
#  3    1015.125  0.000000  0.000000        0.000000  0.000000e+00
#  4    1015.175  0.000000  0.000000        0.000000  0.000000e+00
#  ..        ...       ...       ...             ...           ...
#  297  1029.825  0.002974  0.000372        0.002602  6.739159e+07
#  298  1029.875  0.000678 -0.000024        0.000702  8.423948e+06
#  299  1029.925  0.004779  0.000164        0.004616  7.581553e+07
#  300  1029.975  0.004671 -0.000123        0.004794  4.211974e+07
#  301  1030.025  0.003739  0.000351        0.003389  7.581553e+07
#
#  [302 rows x 5 columns],
#  'FGOALS-g3':           rho      Fgen  HeatFlux  FreshwaterFlux       AreaSum
#  0    1014.975  0
           rho      Fgen  HeatFlux  FreshwaterFlux       AreaSum
#  0    1014.975  0.350572  0.036281        0.314291  1.279844e+09
#  1    1015.025  0.318797  0.032654        0.286143  1.222349e+09
#  2    1015.075  0.268185  0.036242        0.231943  1.229438e+09
#  3    1015.125  0.248100  0.041572        0.206528  1.167784e+09
#  4    1015.175  0.281443  0.032904        0.248539  1.346973e+09
#  ..        ...       ...       ...             ...           ...
#  297  1029.825  0.000000  0.000000        0.000000  0.000000e+00
#  298  1029.875  0.000000  0.000000        0.000000  0.000000e+00
#  299  1029.925  0.000000  0.000000        0.000000  0.000000e+00
#  300  1029.975  0.000000  0.000000        0.000000  0.000000e+00
#  301  1030.025  0.000000  0.000000        0.000000  0.000000e+00
#
#  [302 rows x 5 columns],
#  'NorESM2-LM':           rho      Fgen  HeatFlux  FreshwaterFlux       AreaSum
#  0    1014.975  0.240399  0.006269        0.234130  2.781716e+09
#  1    1015.025  0.193253 -0.002609        0.195862  2.545633e+09
#  2    1015.075  0.160831 -0.002975        0.163807  2.585637e+09
#  3    1015.125  0.210011 -0.000668        0.210679  2.585736e+09
#  4    1015.175  0.177401  0.005099        0.172302  2.528830e+09
#  ..        ...       ...       ...             ...           ...
#  297  1029.825 -0.003529 -0.002975       -0.000554  1.972222e+08
#  298  1029.875 -0.014245 -0.012993       -0.001252  1.972222e+08
#  299  1029.925 -0.005762 -0.004813       -0.000949  1.479564e+08
#  300  1029.975 -0.009674 -0.008295       -0.001379  1.232441e+08
#  301  1030.025  0.005880  0.006324       -0.000444  9.865082e+07
#
#  [302 rows x 5 columns]}

# %%
Fgen_dict.keys()
# Out:
# dict_keys(['ACCESS-CM2', 'ACCESS-ESM1-5', 'CAS-ESM2-0', 'CanESM5', 'CanESM5-1', 'FGOALS-f3-L', 'FGOALS-g3', 'GISS-E2-1-G-CC', 'GISS-E2-2-G', 'ICON-ESM-LR', 'MIROC6', 'MPI-ESM1-2-HR', 'MPI-ESM1-2-LR', 'MRI-ESM2-0', 'NorESM2-LM'])

# %%
for model, Fgen in Fgen_dict.items():
    Fgen_clip = Fgen[(Fgen['rho'] >1015)]
    plt.figure(figsize=(8,5))
    plt.plot(Fgen_clip['rho'], Fgen_clip['Fgen'],'--', label = f'Fgen {model}', color = 'black', linewidth=2)
    plt.plot(Fgen_clip['rho'], Fgen_clip['HeatFlux'], label=f'Heat Flux {model}')
    plt.plot(Fgen_clip['rho'], Fgen_clip['FreshwaterFlux'], label=f'Freshwater Flux {model}')
    #plt.plot(Fgen_clip['rho'], Fgen_clip['AreaSum'], label=f'Area {model}')

    plt.xlabel('rho')
    plt.ylabel('Fgen')
    plt.title(model + ' Fgen vs Rho')
    plt.grid(True)
    plt.legend(loc='upper left')
    plt.show()

# %%
Fgen_clip = Fgen[(Fgen['rho'] >1020)]
plt.figure(figsize=(8,5))
plt.plot(Fgen_clip['rho'], Fgen_clip['AreaSum'], label = 'Area Sum')

plt.xlabel('rho')
plt.ylabel('Area Sum')
plt.title('Area vs Rho')
plt.grid(True)
plt.legend(loc='upper right')
plt.show()
