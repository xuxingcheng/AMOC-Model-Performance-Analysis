# %%
import pandas
import matplotlib.pyplot as plt

# %%
import pickle

save_path = "/glade/work/stevenxu/AMOC_models/Fgen_Allmodels_streaming.pkl"
with open(save_path, "rb") as f:
    Fgen_dict = pickle.load(f)
    
Fgen_dict
# Out:
# {'MPI-ESM1-2-LR':           rho      Fgen  HeatFlux  FreshwaterFlux       AreaSum
#  0    1014.975  0.474561  0.022999        0.451561  4.025527e+09
#  1    1015.025  0.400053  0.024438        0.375615  4.202575e+09
#  2    1015.075  0.358059  0.010024        0.348035  4.082248e+09
#  3    1015.125  0.263856  0.046600        0.217257  3.536434e+09
#  4    1015.175  0.447863  0.037841        0.410022  3.917974e+09
#  ..        ...       ...       ...             ...           ...
#  297  1029.825  0.000000  0.000000        0.000000  0.000000e+00
#  298  1029.875  0.000000  0.000000        0.000000  0.000000e+00
#  299  1029.925  0.000000  0.000000        0.000000  0.000000e+00
#  300  1029.975  0.000000  0.000000        0.000000  0.000000e+00
#  301  1030.025  0.000000  0.000000        0.000000  0.000000e+00
#
#  [302 rows x 5 columns]}

# %%
Fgen_dict.keys()
# Out:
# dict_keys(['MPI-ESM1-2-LR'])

# %%
for model, Fgen in Fgen_dict.items():
    Fgen_clip = Fgen[(Fgen['rho'] >1015)]
    plt.figure(figsize=(8,5))
    plt.plot(Fgen_clip['rho'], Fgen_clip['Fgen'],'--', label = f'Fgen {model}', color = 'black', linewidth=2)
    plt.plot(Fgen_clip['rho'], Fgen_clip['HeatFlux'], label=f'Heat Flux {model}')
    plt.plot(Fgen_clip['rho'], Fgen_clip['FreshwaterFlux'], label=f'Freshwater Flux {model}')
    #plt.plot(Fgen_clip['rho'], Fgen_clip['AreaSum'], label=f'Area {model}')

    plt.xlabel('rho')
    plt.ylabel('Fgen')
    plt.title(model + ' Fgen vs Rho')
    plt.grid(True)
    plt.legend(loc='upper left')
    plt.show()

# %%
Fgen_clip = Fgen[(Fgen['rho'] >1020)]
plt.figure(figsize=(8,5))
plt.plot(Fgen_clip['rho'], Fgen_clip['AreaSum'], label = 'Area Sum')

plt.xlabel('rho')
plt.ylabel('Area Sum')
plt.title('Area vs Rho')
plt.grid(True)
plt.legend(loc='upper right')
plt.show()
