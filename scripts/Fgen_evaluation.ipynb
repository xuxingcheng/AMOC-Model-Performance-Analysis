# %%
import os
import numpy as np
import glob
from collections import defaultdict
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import gsw
from pyproj import Geod
import pickle

# %%
save_path = "/glade/work/stevenxu/AMOC_models/ACCESS-CM2_Fgen.pkl"
with open(save_path, "rb") as f:
    Fgen = pickle.load(f)

Fgen
# Out:
# <xarray.DataArray 'Fgen' (rho_center: 36219, time: 240)> Size: 70MB
# dask.array<getitem, shape=(36219, 240), dtype=float64, chunksize=(36219, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * time        (time) object 2kB 1430-01-16 12:00:00 ... 1449-12-16 12:00:00
#   * rho_center  (rho_center) float64 290kB 1.003e+03 1.003e+03 ... 1.04e+03

# %%
Fgen.isel(time = 50).sel(rho_center= slice(1022,1030)).plot(x = 'rho_center')

# %%
Fgen.mean(dim="time").sel(rho_center= slice(1022,1030)).plot(x = 'rho_center')
