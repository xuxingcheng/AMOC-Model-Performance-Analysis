# %%
import os
import numpy as np
import glob
from collections import defaultdict
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import gsw
from pyproj import Geod
import pickle

# %%
save_path = "/glade/work/stevenxu/AMOC_models/CESM1_Fgen.pkl"
with open(save_path, "rb") as f:
    Fgen = pickle.load(f)

Fgen
# Out:
# <xarray.DataArray 'Fgen' (rho_intervals: 513, time: 6000)> Size: 25MB
# array([[ 0.        ,         nan,         nan, ...,         nan,
#                 nan, -1.00474701],
#        [        nan,         nan,         nan, ..., -1.28631797,
#         -5.07759362,         nan],
#        [        nan,         nan,         nan, ..., -2.18147442,
#                 nan,         nan],
#        ...,
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan]])
# Coordinates:
#   * time           (time) object 48kB 2001-02-01 00:00:00 ... 2501-01-01 00:0...
#   * rho_intervals  (rho_intervals) int64 4kB 0 1 2 3 4 5 ... 508 509 510 511 512
#     rho_center     (rho_intervals) float64 4kB 1.004e+03 1.004e+03 ... 1.029e+03

# %%
Fgen.isel(time = slice(-360, None)).mean(dim ='time').isel(rho_intervals = slice(350,600)).plot(x = 'rho_center')
